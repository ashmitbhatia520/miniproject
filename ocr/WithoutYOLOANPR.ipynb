# %%
import cv2

# %%
# !pip install easyocr
# !pip install imutils
# Out:
# Requirement already satisfied: easyocr in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (1.7.2)
# Requirement already satisfied: torch in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (2.5.1)
# Requirement already satisfied: torchvision>=0.5 in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (0.20.1)
# Requirement already satisfied: opencv-python-headless in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (4.10.0.84)
# Requirement already satisfied: scipy in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (1.14.1)
# Requirement already satisfied: numpy in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (11.0.0)
# Requirement already satisfied: scikit-image in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (0.24.0)
# Requirement already satisfied: python-bidi in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (0.6.3)
# Requirement already satisfied: PyYAML in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (6.0.1)
# Requirement already satisfied: Shapely in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (2.0.6)
# Requirement already satisfied: pyclipper in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (1.3.0.post6)
# Requirement already satisfied: ninja in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from easyocr) (1.11.1.2)
# Requirement already satisfied: filelock in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from torch->easyocr) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from torch->easyocr) (4.12.2)
# Requirement already satisfied: networkx in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from torch->easyocr) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from torch->easyocr) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from torch->easyocr) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from sympy==1.13.1->torch->easyocr) (1.3.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->easyocr) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->easyocr) (2024.9.20)
# Requirement already satisfied: packaging>=21 in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->easyocr) (23.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch->easyocr) (2.1.2)
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: C:\Users\ashmit bhatia\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip
# Requirement already satisfied: imutils in c:\users\ashmit bhatia\appdata\local\programs\python\python311\lib\site-packages (0.5.4)
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: C:\Users\ashmit bhatia\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import cv2
from matplotlib import pyplot as plt
import easyocr
import imutils
import numpy as np

# %%
img = cv2.imread(r'C:\Users\ashmit bhatia\Downloads\data-20241213T152954Z-001\data\109.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %%
bfilter = cv2.bilateralFilter(gray,11,17,17)
edged = cv2.Canny(bfilter, 30, 200)
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key = cv2.contourArea, reverse = True)[:10]

# %%
location = None
for con in contours:
    approx = cv2.approxPolyDP(con, 10, True)
    if len(approx) == 4:
        location = approx
        break

# %%
location
# Out:
# array([[[360,  14]],
#
#        [[ 17,  19]],
#
#        [[ 11,  86]],
#
#        [[353,  92]]], dtype=int32)

# %%
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], 0, 255,-1)
new_image = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %%
(x,y) = np.where(mask == 255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(cropped_image)
result
extracted_text = []
for detection in result:
    text = detection[1]  # The text is stored at index 1 in each detection
    extracted_text.append(text)

# Now, 'extracted_text' will contain the extracted text from the image
print(extracted_text)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ['Tn66 U 8215']

# %%
import pandas as pd
with open("saving.csv", "w", encoding = "utf-8"):
# Out:
#   Cell In[29], line 3
#
#     ^
# SyntaxError: incomplete input

# %%
text = result[0][-2]
font = cv2.FONT_HERSHEY_SIMPLEX
res = cv2.putText(img, text = text, org = (approx[0][0][0], approx[1][0][1]+60), fontFace = font, fontScale = 1, color = (0,255,0), thickness = 2, lineType = cv2.LINE_AA)
res = cv2.rectangle(img, tuple(approx[0][0]),tuple(approx[2][0]), (0,255,0),3)
plt.imshow(res)

# %%
import csv
import os

csv_file = r"C:\Users\ashmit bhatia\Downloads\ANPR-main\ANPR-main\numberplate.csv"

file_exists = True
try:
    with open(csv_file, 'r') as file:
        pass
except FileNotFoundError:
    file_exists = False

try:
    with open(csv_file, mode='a' if file_exists else 'w', newline='') as file:
        writer = csv.writer(file)

        if not file_exists:
            writer.writerow(['PLATE NUMBER'])
        writer.writerow(extracted_text)

        print(f'Output data has been saved to {csv_file}.')
except PermissionError:
    print(f"Permission denied: Unable to write to '{csv_file}'. Please check if the file is open or if you have the necessary permissions.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Output data has been saved to C:\Users\ashmit bhatia\Downloads\ANPR-main\ANPR-main\numberplate.csv.
